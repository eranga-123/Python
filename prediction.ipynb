# %%
import pandas as pd
import numpy as np

# %%
data =  pd.read_csv('smith.csv')

# %%
data.head()
# Out:
#   Runs Mins   BF 4s 6s      SR Pos Dismissal  Inns  Column1  Opposition  \
# 0    1    5    7  0  0   14.28   8       lbw     1      NaN  v Pakistan
# 1   12   32   17  1  0   70.58   9       lbw     3      NaN  v Pakistan
# 2   10    9    8  2  0  125.00   8    bowled     1      NaN  v Pakistan
# 3   77  130  100  9  2   77.00   8    bowled     3      NaN  v Pakistan
# 4    7   46   37  0  0   18.91   6    caught     1      NaN   v England
#
#    Ground Start DateAscending           _1
# 0  Lord's           7/13/2010  Test # 1963
# 1  Lord's           7/13/2010  Test # 1963
# 2   Leeds           7/21/2010  Test # 1965
# 3   Leeds           7/21/2010  Test # 1965
# 4   Perth          12/16/2010  Test # 1984

# %%
data.describe()
# Out:
#              Inns  Column1
# count  145.000000      0.0
# mean     2.324138      NaN
# std      1.098501      NaN
# min      1.000000      NaN
# 25%      1.000000      NaN
# 50%      2.000000      NaN
# 75%      3.000000      NaN
# max      4.000000      NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Runs                 145 non-null    object
#  1   Mins                 145 non-null    object
#  2   BF                   145 non-null    object
#  3   4s                   145 non-null    object
#  4   6s                   145 non-null    object
#  5   SR                   145 non-null    object
#  6   Pos                  145 non-null    object
#  7   Dismissal            145 non-null    object
#  8   Inns                 145 non-null    int64
#  9   Column1              0 non-null      float64
#  10  Opposition           145 non-null    object
#  11  Ground               145 non-null    object
#  12  Start DateAscending  145 non-null    object
#  13  _1                   145 non-null    object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 16.0+ KB

# %%
data = data.drop(columns  = ['_1','Column1'])

# %%
data.head()
# Out:
#   Runs Mins   BF 4s 6s      SR Pos Dismissal  Inns  Opposition  Ground  \
# 0    1    5    7  0  0   14.28   8       lbw     1  v Pakistan  Lord's
# 1   12   32   17  1  0   70.58   9       lbw     3  v Pakistan  Lord's
# 2   10    9    8  2  0  125.00   8    bowled     1  v Pakistan   Leeds
# 3   77  130  100  9  2   77.00   8    bowled     3  v Pakistan   Leeds
# 4    7   46   37  0  0   18.91   6    caught     1   v England   Perth
#
#   Start DateAscending
# 0           7/13/2010
# 1           7/13/2010
# 2           7/21/2010
# 3           7/21/2010
# 4          12/16/2010

# %%
data.isna().sum()
# Out:
# Runs                   0
# Mins                   0
# BF                     0
# 4s                     0
# 6s                     0
# SR                     0
# Pos                    0
# Dismissal              0
# Inns                   0
# Opposition             0
# Ground                 0
# Start DateAscending    0
# dtype: int64

# %%
len(data['Runs'])
# Out:
# 145

# %%
inings  = list(range(1,146))

# %%
data['Inings'] = inings

# %%
data.head()
# Out:
#   Runs Mins   BF 4s 6s      SR Pos Dismissal  Inns  Opposition  Ground  \
# 0    1    5    7  0  0   14.28   8       lbw     1  v Pakistan  Lord's
# 1   12   32   17  1  0   70.58   9       lbw     3  v Pakistan  Lord's
# 2   10    9    8  2  0  125.00   8    bowled     1  v Pakistan   Leeds
# 3   77  130  100  9  2   77.00   8    bowled     3  v Pakistan   Leeds
# 4    7   46   37  0  0   18.91   6    caught     1   v England   Perth
#
#   Start DateAscending  Inings
# 0           7/13/2010       1
# 1           7/13/2010       2
# 2           7/21/2010       3
# 3           7/21/2010       4
# 4          12/16/2010       5

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(data = data, x= 'Inings' , y = 'Runs')

# %%
plt.bar(data['Inings'],data['Runs'])
plt.yticks(data['Runs'])


plt.show()
plt.rcParams['figure.figsize']= 20,10

# %%
import seaborn as sns

# %%
# pd.to_numeric(data['Runs'])

# %%
results = data.groupby('Inings')

# %%
# plt.bar(data['Inings'],results['Runs'])
# plt.xticks(data['Inings'])
# plt.ylabel('Runs')
# plt.xlabel('Inings')
# plt.show()
# plt.rcParams['figure.figsize']= 20,10

# %%
data['Runs'].head(20)
# Out:
# 0       1
# 1      12
# 2      10
# 3      77
# 4       7
# 5      36
# 6       6
# 7      38
# 8      18
# 9     54*
# 10     92
# 11      5
# 12     46
# 13     18
# 14     53
# 15     17
# 16      2
# 17      1
# 18     89
# 19     19
# Name: Runs, dtype: object

# %%
# data['Rns']=data['Runs'].str[-1:4]='*'
# data['Rns'].head(40)

# %%
data['Runs'] = data['Runs'].str.replace(r'*', '')
data['Runs'].head(40)
# Out:
# 0       1
# 1      12
# 2      10
# 3      77
# 4       7
# 5      36
# 6       6
# 7      38
# 8      18
# 9      54
# 10     92
# 11      5
# 12     46
# 13     18
# 14     53
# 15     17
# 16      2
# 17      1
# 18     89
# 19     19
# 20     17
# 21      2
# 22    138
# 23      7
# 24     31
# 25      0
# 26      6
# 27     23
# 28    111
# 29     15
# 30     19
# 31    DNB
# 32    115
# 33      7
# 34    100
# 35    DNB
# 36     49
# 37      0
# 38     84
# 39     36
# Name: Runs, dtype: object

# %%
data['Index']= data['Runs']

# %%
# Set the index of the DataFrame to the country name
data_with_index = data.set_index("Index")
data_with_index.head()
# Out:
#       Runs Mins   BF 4s 6s      SR Pos Dismissal  Inns  Opposition  Ground  \
# Index
# 1        1    5    7  0  0   14.28   8       lbw     1  v Pakistan  Lord's
# 12      12   32   17  1  0   70.58   9       lbw     3  v Pakistan  Lord's
# 10      10    9    8  2  0  125.00   8    bowled     1  v Pakistan   Leeds
# 77      77  130  100  9  2   77.00   8    bowled     3  v Pakistan   Leeds
# 7        7   46   37  0  0   18.91   6    caught     1   v England   Perth
#
#       Start DateAscending  Inings
# Index
# 1               7/13/2010       1
# 12              7/13/2010       2
# 10              7/21/2010       3
# 77              7/21/2010       4
# 7              12/16/2010       5

# %%
# With the index, we can drop the rows for a single country with its name
data_with_index = data_with_index.drop(["DNB","sub"])
data_with_index.head(40)
# Out:
#       Runs Mins   BF  4s 6s      SR Pos Dismissal  Inns      Opposition  \
# Index
# 1        1    5    7   0  0   14.28   8       lbw     1      v Pakistan
# 12      12   32   17   1  0   70.58   9       lbw     3      v Pakistan
# 10      10    9    8   2  0  125.00   8    bowled     1      v Pakistan
# 77      77  130  100   9  2   77.00   8    bowled     3      v Pakistan
# 7        7   46   37   0  0   18.91   6    caught     1       v England
# 36      36   83   62   2  0   58.06   6    caught     3       v England
# 6        6   18   15   0  0   40.00   6    caught     1       v England
# 38      38   91   67   6  0   56.71   6    bowled     3       v England
# 18      18   85   53   1  0   33.96   7    caught     1       v England
# 54      54  132   90   6  0   60.00   7   not out     3       v England
# 92      92  236  185  10  1   49.72   5   stumped     1         v India
# 5        5   23   19   0  0   26.31   4    bowled     3         v India
# ...

# %%
data= data_with_index.reset_index(drop=True, inplace=True)
data_with_index.head(40)
# Out:
#    Runs Mins   BF  4s 6s      SR Pos Dismissal  Inns      Opposition  \
# 0     1    5    7   0  0   14.28   8       lbw     1      v Pakistan
# 1    12   32   17   1  0   70.58   9       lbw     3      v Pakistan
# 2    10    9    8   2  0  125.00   8    bowled     1      v Pakistan
# 3    77  130  100   9  2   77.00   8    bowled     3      v Pakistan
# 4     7   46   37   0  0   18.91   6    caught     1       v England
# 5    36   83   62   2  0   58.06   6    caught     3       v England
# 6     6   18   15   0  0   40.00   6    caught     1       v England
# 7    38   91   67   6  0   56.71   6    bowled     3       v England
# 8    18   85   53   1  0   33.96   7    caught     1       v England
# 9    54  132   90   6  0   60.00   7   not out     3       v England
# 10   92  236  185  10  1   49.72   5   stumped     1         v India
# 11    5   23   19   0  0   26.31   4    bowled     3         v India
# 12   46  152  145   3  2   31.72   5    caught     1         v India
# ...

# %%
data = data_with_index

# %%
data['Runs']=pd.to_numeric(data['Runs'])

# %%
plt.bar(data['Inings'],data['Runs'])
# plt.yticks(data['Runs'])


plt.show()
plt.rcParams['figure.figsize']= 20,10

# %%
plt.scatter(data = data, x= 'Inings' , y = 'Runs')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Runs                 139 non-null    int64
#  1   Mins                 139 non-null    object
#  2   BF                   139 non-null    object
#  3   4s                   139 non-null    object
#  4   6s                   139 non-null    object
#  5   SR                   139 non-null    object
#  6   Pos                  139 non-null    object
#  7   Dismissal            139 non-null    object
#  8   Inns                 139 non-null    int64
#  9   Opposition           139 non-null    object
#  10  Ground               139 non-null    object
#  11  Start DateAscending  139 non-null    object
#  12  Inings               139 non-null    int64
# dtypes: int64(3), object(10)
# memory usage: 14.2+ KB

# %%
data['Mins']=pd.to_numeric(data['Mins'])
data['BF']=pd.to_numeric(data['BF'])
data['4s']=pd.to_numeric(data['4s'])
data['6s']=pd.to_numeric(data['6s'])
data['SR']=pd.to_numeric(data['SR'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Runs                 139 non-null    int64
#  1   Mins                 139 non-null    int64
#  2   BF                   139 non-null    int64
#  3   4s                   139 non-null    int64
#  4   6s                   139 non-null    int64
#  5   SR                   139 non-null    float64
#  6   Pos                  139 non-null    object
#  7   Dismissal            139 non-null    object
#  8   Inns                 139 non-null    int64
#  9   Opposition           139 non-null    object
#  10  Ground               139 non-null    object
#  11  Start DateAscending  139 non-null    object
#  12  Inings               139 non-null    int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 14.2+ KB

# %%
data['Opposition'] = data['Opposition'].str[1:]

# %%
data['Opposition'].head(40)
# Out:
# 0          Pakistan
# 1          Pakistan
# 2          Pakistan
# 3          Pakistan
# 4           England
# 5           England
# 6           England
# 7           England
# 8           England
# 9           England
# 10            India
# 11            India
# 12            India
# 13            India
# 14          England
# 15          England
# 16          England
# 17          England
# 18          England
# 19          England
# 20          England
# 21          England
# 22          England
# 23          England
# 24          England
# 25          England
# 26          England
# 27          England
# 28          England
# 29          England
# 30          England
# 31          England
# 32          England
# 33     South Africa
# 34     South Africa
# 35     South Africa
# 36     South Africa
# 37     South Africa
# 38         Pakistan
# 39         Pakistan
# Name: Opposition, dtype: object

# %%
plt.plot(data['Runs'].groupby(data['Pos']).mean())

# %%
data.groupby(['Opposition']).mean()
# Out:
#                     Runs        Mins          BF        4s        6s  \
# Opposition
#  Bangladesh    29.750000   74.000000   54.500000  3.750000  0.000000
#  England       58.333333  159.229167  105.375000  6.625000  0.354167
#  India         62.214286  156.107143  112.964286  6.607143  0.321429
#  New Zealand   54.071429  147.928571  106.928571  6.214286  0.214286
#  Pakistan      50.333333  119.733333   83.733333  5.800000  0.266667
#  South Africa  36.647059  100.000000   70.176471  4.823529  0.352941
#  Sri Lanka     41.166667  100.666667   79.666667  3.166667  0.166667
#  West Indies   71.000000  163.428571  116.714286  6.000000  0.428571
#
#                       SR      Inns      Inings
# Opposition
#  Bangladesh    81.710000  3.000000  105.500000
#  England       53.244583  2.187500   56.541667
#  India         52.798571  2.214286   84.500000
#  New Zealand   55.943571  2.214286   93.714286
#  Pakistan      61.659333  2.200000   60.400000
# ...

# %%
data.groupby(['Opposition']).sum()
# Out:
#                Runs  Mins    BF   4s  6s       SR  Inns  Inings
# Opposition
#  Bangladesh     119   296   218   15   0   326.84    12     422
#  England       2800  7643  5058  318  17  2555.74   105    2714
#  India         1742  4371  3163  185   9  1478.36    62    2366
#  New Zealand    757  2071  1497   87   3   783.21    31    1312
#  Pakistan       755  1796  1256   87   4   924.89    33     906
#  South Africa   623  1700  1193   82   6   874.81    41    1425
#  Sri Lanka      247   604   478   19   1   314.04    18     489
#  West Indies    497  1144   817   42   3   479.90    15     437

# %%
df= (data.groupby('Opposition')['Runs'].mean())
df.plot(kind='bar', title='ddsf', ylabel='Opposition',
         xlabel='Runs', figsize=(6, 5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-c62aad073832> in <module>
#       1 df= (data.groupby('Opposition')['Runs'].mean())
#       2 df.plot(kind='bar', title='ddsf', ylabel='Opposition',
# ----> 3          xlabel='Runs', figsize=(6, 5))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
train= data[0:120]
test = data[120:]

# %%
train
# Out:
#      Runs  Mins   BF  4s  6s      SR Pos Dismissal  Inns     Opposition  \
# 0       1     5    7   0   0   14.28   8       lbw     1       Pakistan
# 1      12    32   17   1   0   70.58   9       lbw     3       Pakistan
# 2      10     9    8   2   0  125.00   8    bowled     1       Pakistan
# 3      77   130  100   9   2   77.00   8    bowled     3       Pakistan
# 4       7    46   37   0   0   18.91   6    caught     1        England
# ..    ...   ...  ...  ..  ..     ...  ..       ...   ...            ...
# 115     5    19   18   1   0   27.77   4    caught     2   South Africa
# 116     7    29   21   0   1   33.33   4    caught     4   South Africa
# 117   144   336  219  16   2   65.75   4    bowled     1        England
# 118   142   326  207  14   0   68.59   4    caught     3        England
# 119    92   264  161  14   0   57.14   4       lbw     2        England
#
#          Ground Start DateAscending  Inings
# 0        Lord's           7/13/2010       1
# ...

# %%
test
# Out:
#      Runs  Mins   BF  4s  6s      SR Pos Dismissal  Inns    Opposition  \
# 120   211   513  319  24   2   66.14   4    caught     1       England
# 121    82   155   92  11   0   89.13   4    caught     3       England
# 122    80   261  145   9   1   55.17   4       lbw     2       England
# 123    23    88   53   4   0   43.39   4    caught     4       England
# 124     4    17   10   1   0   40.00   4    bowled     2      Pakistan
# 125    36   121   64   2   0   56.25   4    caught     1      Pakistan
# 126    43   190  164   4   0   26.21   4    caught     1   New Zealand
# 127    16    40   28   3   0   57.14   4    caught     3   New Zealand
# 128    85   354  242   8   1   35.12   4    caught     1   New Zealand
# 129     7    17   11   1   0   63.63   4    caught     3   New Zealand
# 130    63   217  182   4   0   34.61   4    caught     1   New Zealand
# 131     1    45   29   0   0    3.44   4    caught     2         India
# ...

# %%
from sklearn.preprocessing import LabelEncoder
category = ['Pos','Opposition','SR', 'Inns']

encoder  = LabelEncoder()
for i in category :
    train[i]= encoder.fit_transform(train[i])
train.dtypes
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Runs                    int64
# Mins                    int64
# BF                      int64
# 4s                      int64
# 6s                      int64
# SR                      int64
# Pos                     int32
# Dismissal              object
# Inns                    int64
# Opposition              int32
# Ground                 object
# Start DateAscending    object
# Inings                  int64
# dtype: object

# %%
#Import the models
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold   #For K-fold cross validation
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics
def classification_model(model, data, predictors, outcome):
  #Fit the model:
  model.fit(data[predictors],data[outcome])
  
  #Make predictions on training set:
  predictions = model.predict(data[predictors])
  
  #Print accuracy
  accuracy = metrics.accuracy_score(predictions,data[outcome])
  print ("Accuracy : %s" % "{0:.3%}".format(accuracy))
#Perform k-fold cross-validation with 5 folds
  kf = KFold(n_splits=5)
  error = []
  for train, test in kf.split(data[predictors]):
    # Filter training data
    train_predictors = (data[predictors].iloc[train,:])
    
    # The target we're using to train the algorithm.
    train_target = data[outcome].iloc[train]
    
    # Training the algorithm using the predictors and target.
    model.fit(train_predictors, train_target)
    
    #Record error from each cross-validation run
    error.append(model.score(data[predictors].iloc[test,:], data[outcome].iloc[test]))
 
  print ("Cross-Validation Score : %s" % "{0:.3%}".format(np.mean(error)))

# %%
outcome_var = 'Runs'
model = LogisticRegression()
predictor_var = ['Pos','Opposition','Inns']
classification_model(model, train,predictor_var,outcome_var)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
model = DecisionTreeClassifier() 
predictor_var = ['Pos','Opposition','Inns']
classification_model(model, train,predictor_var,outcome_var)
# Out:
# Accuracy : 58.333%
# Cross-Validation Score : 1.667%

# %%
model = RandomForestClassifier(n_estimators=100)
predictor_var = ['Pos','Opposition','Inns']
classification_model(model, train,predictor_var,outcome_var)
# Out:
# Accuracy : 58.333%
# Cross-Validation Score : 0.833%

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
x= train[['Pos','Inns']]
y= train['Runs']
regr.fit(x, y)
predicted= regr.predict([[4,1]])
predicted.round()
# Out:
# array([35.])
